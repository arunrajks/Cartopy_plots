# %%
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# ## load data

# %%
ds=xr.open_dataset('/data/cmems/dataset-armor-3d-rep-monthly_1668590140459.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 156, latitude: 85, longitude: 161, depth: 50)
# Coordinates:
#   * depth      (depth) int16 0 5 10 15 20 25 ... 3000 3500 4000 4500 5000 5500
#   * latitude   (latitude) float32 29.88 30.12 30.38 30.62 ... 50.38 50.62 50.88
#   * time       (time) datetime64[ns] 1993-01-16 ... 2005-12-16
#   * longitude  (longitude) float32 279.9 280.1 280.4 280.6 ... 319.4 319.6 319.9
# Data variables:
#     mlotst     (time, latitude, longitude) float32 ...
#     zo         (time, depth, latitude, longitude) float32 ...
#     to         (time, depth, latitude, longitude) float32 ...
#     so         (time, depth, latitude, longitude) float32 ...
#     ugo        (time, depth, latitude, longitude) float32 ...
#     vgo        (time, depth, latitude, longitude) float32 ...
# Attributes:
#     description:       ARMOR3D REP CMEMS December 2020 Release
#     title:             ARMOR3D REP - TSHUVMld Global Ocean Observation-based ...
# ...

# %%
ds.to.sel(latitude=38,depth=0,method='nearest').plot(figsize=(8,12),cmap='RdYlBu')

# %%
ds.to.sel(longitude=300,depth=0,method='nearest').plot(figsize=(8,12))

# %%
ds.to.sel(longitude=300,latitude=40,method='nearest')[:,:-6].plot(figsize=(8,12),x='time',yincrease=False)

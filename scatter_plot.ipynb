# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # seoul bike usage data

# %%
df = pd.read_csv(
    "data/SeoulBikeData.csv"
)

df['Date']=pd.to_datetime(df['Date'])
df=df.set_index('Date')
df = df.dropna(axis=1)
# df.columns = colum_names


df
# Out:
# /var/folders/qk/1gnhnhxn2m91qb1gz4tvnd240000gn/T/ipykernel_29476/4273864422.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date']=pd.to_datetime(df['Date'])
#             Rented Bike Count  Hour  Temperature(C)  Humidity()  \
# Date
# 2017-01-12                254     0            -5.2          37
# 2017-01-12                204     1            -5.5          38
# 2017-01-12                173     2            -6.0          39
# 2017-01-12                107     3            -6.2          40
# 2017-01-12                 78     4            -6.0          36
# ...                       ...   ...             ...         ...
# 2018-11-30               1003    19             4.2          34
# 2018-11-30                764    20             3.4          37
# 2018-11-30                694    21             2.6          39
# 2018-11-30                712    22             2.1          41
# 2018-11-30                584    23             1.9          43
#
#             Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# Date
# 2017-01-12               2.2              2000                     -17.6
# 2017-01-12               0.8              2000                     -17.6
# 2017-01-12               1.0              2000                     -17.7
# 2017-01-12               0.9              2000                     -17.6
# 2017-01-12               2.3              2000                     -18.6
# ...                      ...               ...                       ...
# 2018-11-30               2.6              1894                     -10.3
# 2018-11-30               2.3              2000                      -9.9
# 2018-11-30               0.3              1968                      -9.9
# 2018-11-30               1.0              1859                      -9.8
# 2018-11-30               1.3              1909                      -9.3
#
#             Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# Date
# 2017-01-12                      0.0           0.0            0.0  Winter
# 2017-01-12                      0.0           0.0            0.0  Winter
# 2017-01-12                      0.0           0.0            0.0  Winter
# 2017-01-12                      0.0           0.0            0.0  Winter
# 2017-01-12                      0.0           0.0            0.0  Winter
# ...                             ...           ...            ...     ...
# 2018-11-30                      0.0           0.0            0.0  Autumn
# 2018-11-30                      0.0           0.0            0.0  Autumn
# 2018-11-30                      0.0           0.0            0.0  Autumn
# 2018-11-30                      0.0           0.0            0.0  Autumn
# 2018-11-30                      0.0           0.0            0.0  Autumn
#
#                Holiday Functioning Day
# Date
# 2017-01-12  No Holiday             Yes
# 2017-01-12  No Holiday             Yes
# 2017-01-12  No Holiday             Yes
# 2017-01-12  No Holiday             Yes
# 2017-01-12  No Holiday             Yes
# ...                ...             ...
# 2018-11-30  No Holiday             Yes
# 2018-11-30  No Holiday             Yes
# 2018-11-30  No Holiday             Yes
# 2018-11-30  No Holiday             Yes
# 2018-11-30  No Holiday             Yes
#
# [8760 rows x 13 columns]

# %%
plt.subplots(figsize=(14, 14))
i = 1
for label in df.columns[1:]:
    plt.subplot(4, 3, i)
    plt.scatter(df[label], df[df.columns[0]])
    plt.ylabel("bilke_count")
    plt.xlabel(label)
    i += 1

plt.tight_layout()
# Out:
# /var/folders/qk/1gnhnhxn2m91qb1gz4tvnd240000gn/T/ipykernel_29476/205060080.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4, 3, i)
